# %%
import pandas as pd
import numpy as np

malaria_models = {
    "eos4rta": "MMV",
    "eos4zfy": "MAIP",
    "eos7kpb": "H3D",
}

adme_models = {
    "eos7d58": "ADMET",
    "eos39dp": "DMPK",
}

# %% [markdown]
# ## MMV

# %%
df = pd.read_csv("../processed/eos4rta_all_mols.csv")
df = df.sort_values(by=["NF54_IC50_72h_1uM"], ascending=False)
df
# Out:
#                              key  \
# 124  NWZBNZUABGSPSN-UHFFFAOYSA-N
# 101  XPIXCPCSKJDZLU-MRJPKMESSA-N
# 18   UIOJPVZTRKXUSH-XCVCLJGOSA-N
# 179  VKZXVDMHCBCMCO-UHFFFAOYSA-N
# 223  NGPDQWFWZNXVLZ-UHFFFAOYSA-N
# ..                           ...
# 189  DOOTYTYQINUNNV-UHFFFAOYSA-N
# 99   HLRKFHIIGKCJEW-UHFFFAOYSA-N
# 207  UXDAWVUDZLBBAM-UHFFFAOYSA-N
# 13   COLNVLDHVKWLRT-UHFFFAOYSA-N
# 8    ZDLIFNAOCJUWIZ-UHFFFAOYSA-N
#
#                                                  input  NF54_IC50_72h_1uM  \
# 124  O=C1CC(c2ccc(O)c(O)c2)c2c(cc(O)c3c2OC(c2ccc(O)...           0.437813
# 101  COc1cc(/C=C/C(=O)OCC2OC(Oc3c(-c4ccc(O)cc4)oc4c...           0.414814
# 18   O=C(/C=C/c1ccc(O)cc1)OCOC1OC(Oc2c(-c3ccc(O)cc3...           0.410047
# 179  CCC(C)C1NC(=O)C(CCC(=O)O)N(C)C(=O)C(C(C)C)N(C)...           0.409753
# 223  CCCCCC(=O)NC(CC(=O)O)C(=O)NC1C(=O)NC(Cc2ccc(O)...           0.393823
# ..                                                 ...                ...
# 189                   CCOC(=O)CC(O)(CC(=O)OCC)C(=O)OCC           0.090786
# 99            COC(=O)C(Cc1ccccc1)NC(=O)NCCc1ccc(OC)cc1           0.088261
# 207                              CCN(CC)C(=O)Cc1ccccc1           0.077589
# 13                                 NC(Cc1ccccc1)C(=O)O           0.074057
# 8                          CC(N)C1CCC(C(=O)N2CCOCC2)O1           0.071979
#
#      NF54_50PercInh_LDH  NF54_50PercInh_LUM
# 124            0.298811            0.578608
# 101            0.321077            0.710555
# 18             0.260181            0.472473
# 179            0.174973            0.184339
# 223            0.161324            0.483786
# ..                  ...                 ...
# 189            0.031693            0.010017
# 99             0.020627            0.132840
# 207            0.002026            0.028600
# 13             0.001492            0.021335
# 8              0.001633            0.010017
#
# [384 rows x 5 columns]

# %% [markdown]
# ## MAIP

# %%
df = pd.read_csv("../processed/eos4zfy_all_mols.csv")
df = df.sort_values(by="model_score", ascending=False)
df
# Out:
#                              key  \
# 294  XRUBIEUDSSLMOV-UHFFFAOYSA-N
# 372  UOWFQGKGXMGYLA-UHFFFAOYSA-N
# 350  LURGILDDCOKZRE-UHFFFAOYSA-N
# 269  NRTMMFZTXXHFPV-UHFFFAOYSA-N
# 179  VKZXVDMHCBCMCO-UHFFFAOYSA-N
# ..                           ...
# 1    FWULQXYJOANGSS-UHFFFAOYSA-N
# 368  RMUJWENALAQPCS-SREVYHEPSA-N
# 299  WQBURULAXWBFLG-UHFFFAOYSA-N
# 13   COLNVLDHVKWLRT-UHFFFAOYSA-N
# 286  DZIILFGADWDKMF-UHFFFAOYSA-N
#
#                                                  input  model_score
# 294  COc1ccc(CC2C(=O)OC(C)C(NC(=O)C(CC(C)C)N(C)C(=O...   118.212133
# 372  CCCC1(C2OC(C3OC(O)(CO)C(C)CC3C)CC2C)CC(OC2CCC(...   113.996776
# 350  CCC(C)C1NC(=O)C(Cc2ccc(OC)cc2)NC(=O)C(NC(=O)C(...   101.603871
# 269  CCC1CNC(C(=O)N(C)C2C(=O)NC(CC(C)C)C(=O)C3CC(C)...    91.425044
# 179  CCC(C)C1NC(=O)C(CCC(=O)O)N(C)C(=O)C(C(C)C)N(C)...    70.049159
# ..                                                 ...          ...
# 1                                CCCC(=O)NC(CCO)C(=O)O     0.338734
# 368                       CCCCC/C=C\CCCCCCCCCCCCC(=O)O     0.318673
# 299            C=CCCCCCCCCC1C(=O)OC(C(=O)O)C1(O)C(=O)O    -0.937223
# 13                                 NC(Cc1ccccc1)C(=O)O    -2.285037
# 286                           C#CCCCCCCCCCCCCCCCC(=O)O    -3.577145
#
# [384 rows x 3 columns]

# %% [markdown]
# ## H3D

# %%
df = pd.read_csv("../processed/eos7kpb_all_mols.csv")
columns = ["key", "input", "pf_nf54", "pf_k1"]
df = df[columns]
df = df.sort_values(by="pf_nf54", ascending=False)
df
# Out:
#                              key  \
# 23   QOWRRUMGFVBSIT-UHFFFAOYSA-N
# 51   LXQFRGHXODSYNA-UHFFFAOYSA-N
# 42   SFAUGFBHUYQMBW-UHFFFAOYSA-N
# 19   DEMVNNCXWGOASJ-UHFFFAOYSA-N
# 50   KRHJUZZZEMFSIW-UHFFFAOYSA-N
# ..                           ...
# 26   MCBYOIJIIOKICY-UHFFFAOYSA-N
# 235  KKRZJBWBZYVFHO-UHFFFAOYSA-N
# 293  BIVRZKNOPNUGJZ-UHFFFAOYSA-N
# 290  GGJRAQULURVTAJ-IUQGRGSQSA-N
# 349  YDGRDDWFYSHYSZ-UHFFFAOYSA-N
#
#                                                  input   pf_nf54     pf_k1
# 23   O=C(OC1Cc2c(O)cc(O)c(Cc3c(O)cc(O)c4c3OC(c3cc(O...  0.685174  0.334620
# 51   O=C(OC1Cc2c(cc(O)c(C3c4c(O)cc(O)cc4OC(c4cc(O)c...  0.656258  0.361194
# 42   CC1c2c(O)cc(O)c(C3c4c(O)cc(O)cc4OC(c4cc(O)c(O)...  0.607218  0.361275
# 19   O=C(OC1C(c2cc(O)c(O)c(O)c2)Oc2c(C3c4c(O)cc(O)c...  0.353530  0.327867
# 50   O=C(OC1Cc2c(cc(O)c(C3c4c(O)cc(O)cc4OC(c4cc(O)c...  0.346784  0.350557
# ..                                                 ...       ...       ...
# 26   CNC(=O)C(Cc1ccccc1)NC(=O)CC1(c2oc(C)cc(=O)c2O)...  0.000044  0.095076
# 235                    CC(C)(O)CNC1C(O)C(O)CC1C1CCCCC1  0.000041  0.170270
# 293     CC(=O)N1CCCN(CCC2CN(C(=O)C3CC3)CCC2CC(=O)O)CC1  0.000039  0.149231
# 290            CC/C=C/C/C=C/C/C=C/CCCCCCCC(=O)OCC(O)CO  0.000033  0.113130
# 349                          CCC(O)CC1CC=CC(CC(C)O)N1C  0.000031  0.173528
#
# [384 rows x 4 columns]

# %% [markdown]
# # ADMET

# %%
df = pd.read_csv("../processed/eos7d58_all_mols.csv")
columns = ['key', 'input', 'Clearance_Hepatocyte_AZ_drugbank_approved_percentile', 'Clearance_Microsome_AZ_drugbank_approved_percentile', 'Half_Life_Obach_drugbank_approved_percentile']
df[columns]
# Out:
#                              key  \
# 0    FZHXIRIBWMQPQF-SLPGGIOYSA-N
# 1    FWULQXYJOANGSS-UHFFFAOYSA-N
# 2    FZWBNHMXJMCXLU-UHFFFAOYSA-N
# 3    FZWBNHMXJMCXLU-UHFFFAOYSA-N
# 4    DWZAJFZEYZIHPO-UHFFFAOYSA-N
# ..                           ...
# 379  APLJPCNYUIMBNB-UHFFFAOYSA-N
# 380  UAUDZVJPLUQNMU-MDZDMXLPSA-N
# 381  ODBRNZZJSYPIDI-UHFFFAOYSA-N
# 382  RVKRJABUQLMQNO-IPZRHRPYSA-N
# 383  RXIRUHYYNOJORF-UHFFFAOYSA-N
#
#                                                  input  \
# 0              N[C@@H](C=O)[C@@H](O)[C@H](O)[C@H](O)CO
# 1                                CCCC(=O)NC(CCO)C(=O)O
# 2    O=CC(O)C(O)C(O)C(O)COC1OC(COC2OC(CO)C(O)C(O)C2...
# 3    O=CC(O)C(O)C(O)C(O)COC1OC(COC2OC(CO)C(O)C(O)C2...
# 4          COc1ccc(-c2oc3cc(O)c(OC)c(O)c3c(=O)c2OC)cc1
# ..                                                 ...
# 379            O=C(CCCCCCCCCCCCCCCCCCCCCCCCCO)OCC(O)CO
# 380                     CCCCCCCC/C=C/CCCCCCCCCCCC(N)=O
# 381  O=c1cc(-c2ccc(O)c(O)c2)oc2cc(O)c(C3OC(CO)C(O)C...
# 382  COc1c(O)ccc2c1C(=O)c1c(O)cc(C)cc1[C@@H]2[C@@H]...
# 383  C=C(CCC(C)C1CC=C2C3=C(CCC21C)C1(C)CCC(O)C(C)(O...
#
#      Clearance_Hepatocyte_AZ_drugbank_approved_percentile  \
# 0                                            65.606824
# 1                                             3.412175
# 2                                            50.329585
# 3                                            50.329585
# 4                                            81.892206
# ..                                                 ...
# 379                                          94.261342
# 380                                          88.794106
# 381                                          31.640171
# 382                                          58.976347
# 383                                          64.327259
#
#      Clearance_Microsome_AZ_drugbank_approved_percentile  \
# 0                                            31.329973
# 1                                             2.946879
# 2                                            59.015122
# 3                                            59.015122
# 4                                            53.392788
# ..                                                 ...
# 379                                          98.100039
# 380                                          94.067468
# 381                                          34.238077
# 382                                          61.962001
# 383                                          87.165568
#
#      Half_Life_Obach_drugbank_approved_percentile
# 0                                       52.074447
# 1                                       35.401318
# 2                                       75.804575
# 3                                       75.804575
# 4                                       55.525397
# ..                                            ...
# 379                                     91.896084
# 380                                     90.500194
# 381                                     87.049244
# 382                                     76.114773
# 383                                     32.880962
#
# [384 rows x 5 columns]

# %% [markdown]
# ## DMPK

# %%
df = pd.read_csv("../processed/eos39dp_all_mols.csv")
columns = ['key', 'input', 'Hepatic Stability', 'Microsomal Half-life Sub-cellular', 'Microsomal Half-life Tissue', 'Microsomal Intrinsic Clearance']
df = df[columns]
df
# Out:
#                              key  \
# 0    FZHXIRIBWMQPQF-SLPGGIOYSA-N
# 1    FWULQXYJOANGSS-UHFFFAOYSA-N
# 2    FZWBNHMXJMCXLU-UHFFFAOYSA-N
# 3    FZWBNHMXJMCXLU-UHFFFAOYSA-N
# 4    DWZAJFZEYZIHPO-UHFFFAOYSA-N
# ..                           ...
# 379  APLJPCNYUIMBNB-UHFFFAOYSA-N
# 380  UAUDZVJPLUQNMU-MDZDMXLPSA-N
# 381  ODBRNZZJSYPIDI-UHFFFAOYSA-N
# 382  RVKRJABUQLMQNO-IPZRHRPYSA-N
# 383  RXIRUHYYNOJORF-UHFFFAOYSA-N
#
#                                                  input  \
# 0              N[C@@H](C=O)[C@@H](O)[C@H](O)[C@H](O)CO
# 1                                CCCC(=O)NC(CCO)C(=O)O
# 2    O=CC(O)C(O)C(O)C(O)COC1OC(COC2OC(CO)C(O)C(O)C2...
# 3    O=CC(O)C(O)C(O)C(O)COC1OC(COC2OC(CO)C(O)C(O)C2...
# 4          COc1ccc(-c2oc3cc(O)c(OC)c(O)c3c(=O)c2OC)cc1
# ..                                                 ...
# 379            O=C(CCCCCCCCCCCCCCCCCCCCCCCCCO)OCC(O)CO
# 380                     CCCCCCCC/C=C/CCCCCCCCCCCC(N)=O
# 381  O=c1cc(-c2ccc(O)c(O)c2)oc2cc(O)c(C3OC(CO)C(O)C...
# 382  COc1c(O)ccc2c1C(=O)c1c(O)cc(C)cc1[C@@H]2[C@@H]...
# 383  C=C(CCC(C)C1CC=C2C3=C(CCC21C)C1(C)CCC(O)C(C)(O...
#
#                          Hepatic Stability  \
# 0    Hepatic stability > 50% at 60 minutes
# 1    Hepatic stability > 50% at 60 minutes
# 2    Hepatic stability > 50% at 60 minutes
# 3    Hepatic stability > 50% at 60 minutes
# 4    Hepatic stability > 50% at 60 minutes
# ..                                     ...
# 379  Hepatic stability > 50% at 60 minutes
# 380                          No prediction
# 381  Hepatic stability > 50% at 60 minutes
# 382  Hepatic stability > 50% at 60 minutes
# 383                          No prediction
#
#                Microsomal Half-life Sub-cellular  \
# 0    Sub-cellular Hepatic Half-life > 30 minutes
# 1    Sub-cellular Hepatic Half-life > 30 minutes
# 2    Sub-cellular Hepatic Half-life > 30 minutes
# 3    Sub-cellular Hepatic Half-life > 30 minutes
# 4    Sub-cellular Hepatic Half-life > 30 minutes
# ..                                           ...
# 379  Sub-cellular Hepatic Half-life > 30 minutes
# 380  Sub-cellular Hepatic Half-life > 30 minutes
# 381  Sub-cellular Hepatic Half-life > 30 minutes
# 382  Sub-cellular Hepatic Half-life > 30 minutes
# 383  Sub-cellular Hepatic Half-life > 30 minutes
#
#                 Microsomal Half-life Tissue  \
# 0     Tissue Hepatic Half-life > 30 minutes
# 1    Tissue Hepatic Half-life <= 30 minutes
# 2     Tissue Hepatic Half-life > 30 minutes
# 3     Tissue Hepatic Half-life > 30 minutes
# 4    Tissue Hepatic Half-life <= 30 minutes
# ..                                      ...
# 379   Tissue Hepatic Half-life > 30 minutes
# 380  Tissue Hepatic Half-life <= 30 minutes
# 381   Tissue Hepatic Half-life > 30 minutes
# 382   Tissue Hepatic Half-life > 30 minutes
# 383  Tissue Hepatic Half-life <= 30 minutes
#
#                      Microsomal Intrinsic Clearance
# 0     Microsomal intrinsic clearance < 12 uL/min/mg
# 1     Microsomal intrinsic clearance < 12 uL/min/mg
# 2     Microsomal intrinsic clearance < 12 uL/min/mg
# 3     Microsomal intrinsic clearance < 12 uL/min/mg
# 4    Microsomal intrinsic clearance >= 12 uL/min/mg
# ..                                              ...
# 379   Microsomal intrinsic clearance < 12 uL/min/mg
# 380   Microsomal intrinsic clearance < 12 uL/min/mg
# 381   Microsomal intrinsic clearance < 12 uL/min/mg
# 382  Microsomal intrinsic clearance >= 12 uL/min/mg
# 383  Microsomal intrinsic clearance >= 12 uL/min/mg
#
# [384 rows x 6 columns]

# %% [markdown]
# ## Concatenate datasets

# %%
df = pd.read_csv("../processed/eos4rta_all_mols.csv")

df_ = pd.read_csv("../processed/eos4zfy_all_mols.csv")["model_score"]
df = pd.concat([df, df_], axis=1)

df_ = pd.read_csv("../processed/eos7kpb_all_mols.csv")[["pf_nf54", "pf_k1"]]
df = pd.concat([df, df_], axis=1)

df_ = pd.read_csv("../processed/eos7d58_all_mols.csv")[['Clearance_Hepatocyte_AZ_drugbank_approved_percentile', 'Clearance_Microsome_AZ_drugbank_approved_percentile', 'Half_Life_Obach_drugbank_approved_percentile']]
df = pd.concat([df, df_], axis=1)

df_ = pd.read_csv("../processed/eos39dp_all_mols.csv")[['Hepatic Stability', 'Microsomal Half-life Sub-cellular', 'Microsomal Half-life Tissue', 'Microsomal Intrinsic Clearance']]
df = pd.concat([df, df_], axis=1)

df.to_csv("../show/all_mols_concatenated_outputs.csv", index=False)

# %% [markdown]
# ## Chemical space exploration of MEP pathway inhibitors

# %%
x_0 = pd.read_csv("../processed/eos4u6p_all_mols.csv")
x_0 = np.array(x_0[x_0.columns[2:]])
x_1 = pd.read_csv("../processed/eos4u6p_mep_activities.csv")
x_1 = np.array(x_1[x_1.columns[2:]])

# %%
x = np.concatenate([x_0, x_1], axis=0)
from sklearn.decomposition import PCA

reducer = PCA(n_components=4)
reducer.fit(x)
p_0 = reducer.transform(x_0)
p_1 = reducer.transform(x_1)

# %%
import matplotlib.pyplot as plt
plt.scatter(p_0[:, 0], p_0[:, 1], label="All Molecules")
plt.scatter(p_1[:, 0], p_1[:, 1], label="MEP Activities")

# %%
plt.scatter(p_0[:, 2], p_0[:, 3], label="All Molecules")
plt.scatter(p_1[:, 2], p_1[:, 3], label="MEP Activities")

# %%
from umap import UMAP

reducer = UMAP(n_components=2)
reducer.fit(x)
p_0 = reducer.transform(x_0)
p_1 = reducer.transform(x_1)

# %%
plt.scatter(p_0[:, 0], p_0[:, 1], label="All Molecules")
plt.scatter(p_1[:, 0], p_1[:, 1], label="MEP Activities")

# %% [markdown]
# ## Train a model

# %%
x_0 = pd.read_csv("../processed/drugbank_eos4u6p.csv")
x_0 = np.array(x_0[x_0.columns[2:]])

# %%
from sklearn.linear_model import LogisticRegression

R = []
for i in range(x_0.shape[0]):
    r = x_0[i,:]
    if np.any(np.isnan(r)):
        continue
    R.append(r)
x_0 = np.array(R)

x = np.concatenate([x_1, x_0], axis=0)

y = np.array([1]*x_1.shape[0] + [0]*x_0.shape[0])

model = LogisticRegression(class_weight="balanced")
model.fit(x, y)

# %% [markdown]
# ## Predict for our molecules

# %%
x_t = pd.read_csv("../processed/eos4u6p_all_mols.csv")
x_t = np.array(x_t[x_t.columns[2:]])

# %%
y_hat = model.predict_proba(x_t)[:,1]

# %%
df = pd.read_csv("../processed/all_mols.csv")
df["mep_prediction"] = y_hat

df.to_csv("../processed/mep_prediction_all_mols.csv", index=False)

# %%
plt.hist(model.predict_proba(x_t)[:,1])
# Out:
# (array([350.,  12.,   7.,   1.,   5.,   3.,   3.,   2.,   0.,   1.]),
#  array([2.74617797e-07, 5.04044005e-02, 1.00808526e-01, 1.51212652e-01,
#         2.01616778e-01, 2.52020904e-01, 3.02425030e-01, 3.52829156e-01,
#         4.03233282e-01, 4.53637408e-01, 5.04041534e-01]),
#  <BarContainer object of 10 artists>)
